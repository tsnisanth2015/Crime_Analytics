# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('d://DataFiles_Backup//bangalore_3k.csv')

# %%
df.rename(columns = {'Unnamed: 0':'Tweet_ID', 'text':'Tweet_Text', 'lang':'Language', 'country':'Country'},inplace=True)

# %%
df.head()
# Out:
#    Tweet_ID                                         Tweet_Text Language  \
# 0         0  Machn wish u Happ birthday da  @ThalaSyed005 😍...       en
# 1         1  Not tryna be cool ✔ And I wanna feel it too\n📸...       en
# 2         2  Icardi, What a player. Inter stays within touc...       en
# 3         3  Will b d last day of all our #Mersal issues ! ...       en
# 4         4  Many ppl around the world r getting #Nougat 7....       en
#
#   Country
# 0   India
# 1   India
# 2   India
# 3   India
# 4   India

# %%
df.head()
# Out:
#    Tweet_ID                                         Tweet_Text Language  \
# 0         0  Machn wish u Happ birthday da  @ThalaSyed005 😍...       en
# 1         1  Not tryna be cool ✔ And I wanna feel it too\n📸...       en
# 2         2  Icardi, What a player. Inter stays within touc...       en
# 3         3  Will b d last day of all our #Mersal issues ! ...       en
# 4         4  Many ppl around the world r getting #Nougat 7....       en
#
#   Country
# 0   India
# 1   India
# 2   India
# 3   India
# 4   India

# %%
df.shape
# Out:
# (3606, 4)

# %%
df.dtypes
# Out:
# Tweet_ID       int64
# Tweet_Text    object
# Language      object
# Country       object
# dtype: object

# %%
df
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 0            0  Machn wish u Happ birthday da  @ThalaSyed005 😍...       en
# 1            1  Not tryna be cool ✔ And I wanna feel it too\n📸...       en
# 2            2  Icardi, What a player. Inter stays within touc...       en
# 3            3  Will b d last day of all our #Mersal issues ! ...       en
# 4            4  Many ppl around the world r getting #Nougat 7....       en
# 5            5  Samvat 2074 will see liquidity-valuations tuss...       en
# 6            6  @timesofindia Is this piece of news visible to...       en
# 7            7  When you lose your excuse, Results will be fou...       en
# 8            8  @CMofKarnataka pl read this. V all know that u...       en
# 9            9  @Rekhta \nखड़े हैं मुझको खरीदार देखने के लिए \...       hi
# 10          10  The way you react towards a problem will deter...       en
# 11          11                                            Fguuuuu      und
# 12          12  @KVsayz Ee photo lo 7 gates unnay, 3 gates clo...       et
# 13          13  Dear young bloods don't do dz kind of stunts @...       en
# 14          14  @KVsayz Podhunne akkadiki vellinattu unnaru ga...       et
# 15          15  @nimmaupendra \n\n Uಪ್ಪಿsm,. Forever https://t...       en
# 16          16  It's been dark and gloomy ride, all I wish for...       en
# 17          17  Happy Birthday @anirudhofficial Waiting for yo...       en
# 18          18  Meera Parida getting felicitated by our Founde...       en
# 19          19  யார்ரா அவன் டேய் ஹன்சுவையே குறு குறுன்னு பாக்க...       ta
# 20          20                                @ibrahimsns அவ்வ்வ்       ta
# 21          21  @OfficeOfRG @rajnathsingh @PMOIndia @sambitswa...       en
# 22          22  Three persons buried alive in a building colla...       en
# 23          23  Animal Activist Nandini paying price for compl...       en
# 24          24  Join the General Electric team! See our latest...       en
# 25          25  ദീപാവലി ആശംസകൾ ആരും മുൻകൂർ തരെണ്ടാ...\nഞാൻ എങ്...       ml
# 26          26  Enjoy the day like it's your last, don't take ...       en
# 27          27  #Mersal Story Leaked? A Video For All Rumour K...       en
# 28          28  Sir your tweets are getting bold day by day. G...       en
# 29          29                Omg ! Where https://t.co/AwUTQ68EgB       en
# ...        ...                                                ...      ...
# 3576      3576  #food #foodie #snacks #nature nature foodyeati...       en
# 3577      3577  @ernestjeffry You mean 80 crores turnover or l...       en
# 3578      3578  પીએમ મોદીએ વેપારીઓને  કર્યો વાયદો, તમારા જુના ...       gu
# 3579      3579  $ULI.V up +18.92% last wk as #UltraLithium sam...       en
# 3580      3580  @iPallaviGoyal u can PLAY with this https://t....       en
# 3581      3581  One Stop solution for the complete #interiorde...       en
# 3582      3582                               @iPallaviGoyal "ALL"      und
# 3583      3583  કોંગ્રેસને પેટમાં દુખે છે અને માથું કુટે છેઃ વ...       gu
# 3584      3584  Can you recommend anyone for this #job? Projec...       en
# 3585      3585  Jacques Kallis, @jacqueskallis75 is now trendi...       en
# 3586      3586  @Swamy39 Rajdeep looked like a mental case aft...       en
# 3587      3587  'sangeet' &amp; 'blot' are now trending in #Ba...       en
# 3588      3588  All the best @NewtonTheFilm for being selected...       en
# 3589      3589  Why are rent agreements only for 11 months?\nh...       en
# 3590      3590                      @iPallaviGoyal &lt;--- STINKS       en
# 3591      3591           Thank you koko 🤗 https://t.co/N6dPr7zd8J       en
# 3592      3592     @iPallaviGoyal  &lt;-- BEGGING FOR HUMILIATION       en
# 3593      3593  Make it your twitter/insta/fb DP for his 23rd ...       en
# 3594      3594  1485sq.ft Plot w/ price of 20.79 lakhs is avai...       en
# 3595      3595  👀 Insider Tips on Broadway by @debbiedares in ...       en
# 3596      3596  And they say, #Kashmir belonged to them. 😂😂😂 h...       en
# 3597      3597                        +10 https://t.co/3emgBBHb3z      und
# 3598      3598  CRUDE OIL ROCKED FROM 3357 TO 3387 +30 PTS BOO...       en
# 3599      3599  HOLY SHIT 2018 @hellfestopenair TIX ARE ALREAD...       en
# 3600      3600  નોટબંધીના કારણે 3 લાખ કરોડ રૂપિયાનું સરકારને સ...       gu
# 3601      3601  @naralokesh Tirupati can be a bigger Eco-syste...       en
# 3602      3602  Rental Space Available for #CambridgeLayout #O...       en
# 3603      3603  Those questioning us on development of Gujarat...       en
# 3604      3604  $AWE.V up +18.75% last wk on no news: WATCH Br...       en
# 3605      3605             @iPallaviGoyal https://t.co/fgjxDy78Ij      und
#
#      Country
# 0      India
# 1      India
# 2      India
# 3      India
# 4      India
# 5      India
# 6      India
# 7      India
# 8      India
# 9      India
# 10     India
# 11     India
# 12     India
# 13     India
# 14     India
# 15     India
# 16     India
# 17     India
# 18     India
# 19     India
# 20     India
# 21     India
# 22     India
# 23     India
# 24     India
# 25     India
# 26     India
# 27     India
# 28     India
# 29     India
# ...      ...
# 3576   India
# 3577   India
# 3578   India
# 3579   India
# 3580   India
# 3581   India
# 3582   India
# 3583   India
# 3584   India
# 3585   India
# 3586   India
# 3587   India
# 3588   India
# 3589   India
# 3590   India
# 3591   India
# 3592   India
# 3593   India
# 3594   India
# 3595   India
# 3596   India
# 3597   India
# 3598   India
# 3599   India
# 3600   India
# 3601   India
# 3602   India
# 3603   India
# 3604   India
# 3605   India
#
# [3606 rows x 4 columns]

# %%
df['Tweet_Text']
# Out:
# 0       Machn wish u Happ birthday da  @ThalaSyed005 😍...
# 1       Not tryna be cool ✔ And I wanna feel it too\n📸...
# 2       Icardi, What a player. Inter stays within touc...
# 3       Will b d last day of all our #Mersal issues ! ...
# 4       Many ppl around the world r getting #Nougat 7....
# 5       Samvat 2074 will see liquidity-valuations tuss...
# 6       @timesofindia Is this piece of news visible to...
# 7       When you lose your excuse, Results will be fou...
# 8       @CMofKarnataka pl read this. V all know that u...
# 9       @Rekhta \nखड़े हैं मुझको खरीदार देखने के लिए \...
# 10      The way you react towards a problem will deter...
# 11                                                Fguuuuu
# 12      @KVsayz Ee photo lo 7 gates unnay, 3 gates clo...
# 13      Dear young bloods don't do dz kind of stunts @...
# 14      @KVsayz Podhunne akkadiki vellinattu unnaru ga...
# 15      @nimmaupendra \n\n Uಪ್ಪಿsm,. Forever https://t...
# 16      It's been dark and gloomy ride, all I wish for...
# 17      Happy Birthday @anirudhofficial Waiting for yo...
# 18      Meera Parida getting felicitated by our Founde...
# 19      யார்ரா அவன் டேய் ஹன்சுவையே குறு குறுன்னு பாக்க...
# 20                                    @ibrahimsns அவ்வ்வ்
# 21      @OfficeOfRG @rajnathsingh @PMOIndia @sambitswa...
# 22      Three persons buried alive in a building colla...
# 23      Animal Activist Nandini paying price for compl...
# 24      Join the General Electric team! See our latest...
# 25      ദീപാവലി ആശംസകൾ ആരും മുൻകൂർ തരെണ്ടാ...\nഞാൻ എങ്...
# 26      Enjoy the day like it's your last, don't take ...
# 27      #Mersal Story Leaked? A Video For All Rumour K...
# 28      Sir your tweets are getting bold day by day. G...
# 29                    Omg ! Where https://t.co/AwUTQ68EgB
#                               ...
# 3576    #food #foodie #snacks #nature nature foodyeati...
# 3577    @ernestjeffry You mean 80 crores turnover or l...
# 3578    પીએમ મોદીએ વેપારીઓને  કર્યો વાયદો, તમારા જુના ...
# 3579    $ULI.V up +18.92% last wk as #UltraLithium sam...
# 3580    @iPallaviGoyal u can PLAY with this https://t....
# 3581    One Stop solution for the complete #interiorde...
# 3582                                 @iPallaviGoyal "ALL"
# 3583    કોંગ્રેસને પેટમાં દુખે છે અને માથું કુટે છેઃ વ...
# 3584    Can you recommend anyone for this #job? Projec...
# 3585    Jacques Kallis, @jacqueskallis75 is now trendi...
# 3586    @Swamy39 Rajdeep looked like a mental case aft...
# 3587    'sangeet' &amp; 'blot' are now trending in #Ba...
# 3588    All the best @NewtonTheFilm for being selected...
# 3589    Why are rent agreements only for 11 months?\nh...
# 3590                        @iPallaviGoyal &lt;--- STINKS
# 3591             Thank you koko 🤗 https://t.co/N6dPr7zd8J
# 3592       @iPallaviGoyal  &lt;-- BEGGING FOR HUMILIATION
# 3593    Make it your twitter/insta/fb DP for his 23rd ...
# 3594    1485sq.ft Plot w/ price of 20.79 lakhs is avai...
# 3595    👀 Insider Tips on Broadway by @debbiedares in ...
# 3596    And they say, #Kashmir belonged to them. 😂😂😂 h...
# 3597                          +10 https://t.co/3emgBBHb3z
# 3598    CRUDE OIL ROCKED FROM 3357 TO 3387 +30 PTS BOO...
# 3599    HOLY SHIT 2018 @hellfestopenair TIX ARE ALREAD...
# 3600    નોટબંધીના કારણે 3 લાખ કરોડ રૂપિયાનું સરકારને સ...
# 3601    @naralokesh Tirupati can be a bigger Eco-syste...
# 3602    Rental Space Available for #CambridgeLayout #O...
# 3603    Those questioning us on development of Gujarat...
# 3604    $AWE.V up +18.75% last wk on no news: WATCH Br...
# 3605               @iPallaviGoyal https://t.co/fgjxDy78Ij
# Name: Tweet_Text, Length: 3606, dtype: object

# %%
en_tweets = df[df.Language=='en']

# %%
en_tweets
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 0            0  Machn wish u Happ birthday da  @ThalaSyed005 😍...       en
# 1            1  Not tryna be cool ✔ And I wanna feel it too\n📸...       en
# 2            2  Icardi, What a player. Inter stays within touc...       en
# 3            3  Will b d last day of all our #Mersal issues ! ...       en
# 4            4  Many ppl around the world r getting #Nougat 7....       en
# 5            5  Samvat 2074 will see liquidity-valuations tuss...       en
# 6            6  @timesofindia Is this piece of news visible to...       en
# 7            7  When you lose your excuse, Results will be fou...       en
# 8            8  @CMofKarnataka pl read this. V all know that u...       en
# 10          10  The way you react towards a problem will deter...       en
# 13          13  Dear young bloods don't do dz kind of stunts @...       en
# 15          15  @nimmaupendra \n\n Uಪ್ಪಿsm,. Forever https://t...       en
# 16          16  It's been dark and gloomy ride, all I wish for...       en
# 17          17  Happy Birthday @anirudhofficial Waiting for yo...       en
# 18          18  Meera Parida getting felicitated by our Founde...       en
# 21          21  @OfficeOfRG @rajnathsingh @PMOIndia @sambitswa...       en
# 22          22  Three persons buried alive in a building colla...       en
# 23          23  Animal Activist Nandini paying price for compl...       en
# 24          24  Join the General Electric team! See our latest...       en
# 26          26  Enjoy the day like it's your last, don't take ...       en
# 27          27  #Mersal Story Leaked? A Video For All Rumour K...       en
# 28          28  Sir your tweets are getting bold day by day. G...       en
# 29          29                Omg ! Where https://t.co/AwUTQ68EgB       en
# 30          30  Our very own Dr. Achyuta Samanta expressing hi...       en
# 31          31                    @Jaggesh2 Nice all the best sir       en
# 34          34  @devaralas @KVsayz Yeah in flow taggindi ninna...       en
# 38          38  On Behalf of #Ajithians around the Globe wishi...       en
# 40          40                          Simplicity is enchanting.       en
# 41          41  @AppleSupport I purchased one app by mistake. ...       en
# 42          42  4 people killed in building collapse after cyl...       en
# ...        ...                                                ...      ...
# 3569      3569  #soup #foodie #snacks foodyeating diy.learning...       en
# 3570      3570      @iPallaviGoyal &lt;-- DESPARATE PIECE OF SHIT       en
# 3571      3571  @blrcitytraffic chaitanya school bus Ka53b5027...       en
# 3572      3572  If u are not getting product in time, if u are...       en
# 3574      3574             @iPallaviGoyal PROUDLY DECLARE WAT U R       en
# 3575      3575                @RKzFandom @RK1610IsMe 8 years ❤️❤️       en
# 3576      3576  #food #foodie #snacks #nature nature foodyeati...       en
# 3577      3577  @ernestjeffry You mean 80 crores turnover or l...       en
# 3579      3579  $ULI.V up +18.92% last wk as #UltraLithium sam...       en
# 3580      3580  @iPallaviGoyal u can PLAY with this https://t....       en
# 3581      3581  One Stop solution for the complete #interiorde...       en
# 3584      3584  Can you recommend anyone for this #job? Projec...       en
# 3585      3585  Jacques Kallis, @jacqueskallis75 is now trendi...       en
# 3586      3586  @Swamy39 Rajdeep looked like a mental case aft...       en
# 3587      3587  'sangeet' &amp; 'blot' are now trending in #Ba...       en
# 3588      3588  All the best @NewtonTheFilm for being selected...       en
# 3589      3589  Why are rent agreements only for 11 months?\nh...       en
# 3590      3590                      @iPallaviGoyal &lt;--- STINKS       en
# 3591      3591           Thank you koko 🤗 https://t.co/N6dPr7zd8J       en
# 3592      3592     @iPallaviGoyal  &lt;-- BEGGING FOR HUMILIATION       en
# 3593      3593  Make it your twitter/insta/fb DP for his 23rd ...       en
# 3594      3594  1485sq.ft Plot w/ price of 20.79 lakhs is avai...       en
# 3595      3595  👀 Insider Tips on Broadway by @debbiedares in ...       en
# 3596      3596  And they say, #Kashmir belonged to them. 😂😂😂 h...       en
# 3598      3598  CRUDE OIL ROCKED FROM 3357 TO 3387 +30 PTS BOO...       en
# 3599      3599  HOLY SHIT 2018 @hellfestopenair TIX ARE ALREAD...       en
# 3601      3601  @naralokesh Tirupati can be a bigger Eco-syste...       en
# 3602      3602  Rental Space Available for #CambridgeLayout #O...       en
# 3603      3603  Those questioning us on development of Gujarat...       en
# 3604      3604  $AWE.V up +18.75% last wk on no news: WATCH Br...       en
#
#      Country
# 0      India
# 1      India
# 2      India
# 3      India
# 4      India
# 5      India
# 6      India
# 7      India
# 8      India
# 10     India
# 13     India
# 15     India
# 16     India
# 17     India
# 18     India
# 21     India
# 22     India
# 23     India
# 24     India
# 26     India
# 27     India
# 28     India
# 29     India
# 30     India
# 31     India
# 34     India
# 38     India
# 40     India
# 41     India
# 42     India
# ...      ...
# 3569   India
# 3570   India
# 3571   India
# 3572   India
# 3574   India
# 3575   India
# 3576   India
# 3577   India
# 3579   India
# 3580   India
# 3581   India
# 3584   India
# 3585   India
# 3586   India
# 3587   India
# 3588   India
# 3589   India
# 3590   India
# 3591   India
# 3592   India
# 3593   India
# 3594   India
# 3595   India
# 3596   India
# 3598   India
# 3599   India
# 3601   India
# 3602   India
# 3603   India
# 3604   India
#
# [2363 rows x 4 columns]

# %%
mask = np.column_stack([df['Tweet_Text'].str.contains("pothole", na=False) for text in df])
mask_pothole = df.loc[mask.any(axis=1)]

# %%
mask_pothole
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 737        737  10+ ppl died in Bangalore due to potholes but ...       en
# 1614      1614  @BBMPCOMM1  Sir,Deadly Road conditions for two...       en
# 1910      1910   @TOIBengaluru As if pothole deaths wr not enough       en
# 2342      2342  No money for filling potholes,CM Karnataka spe...       en
# 2572      2572  AAP ACE champions registered complaint with BB...       en
#
#      Country
# 737    India
# 1614   India
# 1910   India
# 2342   India
# 2572   India

# %%
df['Category'] = ''
df['Sub_Category'] = ''

# %%
df.head()
# Out:
#    Tweet_ID                                         Tweet_Text Language  \
# 0         0  Machn wish u Happ birthday da  @ThalaSyed005 😍...       en
# 1         1  Not tryna be cool ✔ And I wanna feel it too\n📸...       en
# 2         2  Icardi, What a player. Inter stays within touc...       en
# 3         3  Will b d last day of all our #Mersal issues ! ...       en
# 4         4  Many ppl around the world r getting #Nougat 7....       en
#
#   Country Category Sub_Category
# 0   India
# 1   India
# 2   India
# 3   India
# 4   India

# %%
df.dtypes
# Out:
# Tweet_ID         int64
# Tweet_Text      object
# Language        object
# Country         object
# Category        object
# Sub_Category    object
# dtype: object

# %%
Tweets_Categorized = df[(df.Tweet_Text.str.contains('pothole')) | (df.Tweet_Text.str.contains('murder')) | (df.Tweet_Text.str.contains('theft')) | (df.Tweet_Text.str.contains('robbery')) | (df.Tweet_Text.str.contains('accident')) | (df.Tweet_Text.str.contains('cruelty')) | (df.Tweet_Text.str.contains('blast')) | (df.Tweet_Text.str.contains('terror')) | (df.Tweet_Text.str.contains('explosion'))]

# %%
Tweets_Categorized['Category'] = 'Crime'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Tweets_Categorized
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 42          42  4 people killed in building collapse after cyl...       en
# 70          70  4 people killed in building collapse after cyl...       en
# 182        182  @TheAsianAgeNews And Tillerson wl say Pakistan...       en
# 257        257  https://t.co/7uGFf7937r\nBook @UIDAI for murde...       en
# 331        331  Situation of Bangalore railway station. Inviti...       en
# 471        471  #GauriLankesh murder will remain forever  a my...       en
# 482        482  This is man who is accused of roits begining f...       en
# 576        576  Death toll rises to 6 in Ejipura blast in #Ben...       en
# 607        607  Death toll rises to 6 in Ejipura cylinder blas...       en
# 652        652  Death toll rises to 5 in Ejipura cylinder blas...       en
# 737        737  10+ ppl died in Bangalore due to potholes but ...       en
# 999        999  @YusufDFI He's right. Rest of us are disposabl...       en
# 1092      1092  A Hindu Mutt Swamini attends a rally organized...       en
# 1096      1096  Pinarayi Vijayan, the prime accused in Kerala’...       en
# 1315      1315  Siddaramaiah’s SIT probing Gauri Lankesh murde...       en
# 1614      1614  @BBMPCOMM1  Sir,Deadly Road conditions for two...       en
# 1910      1910   @TOIBengaluru As if pothole deaths wr not enough       en
# 2214      2214  Forensic team visits building collapse site at...       en
# 2342      2342  No money for filling potholes,CM Karnataka spe...       en
# 2361      2361  @thekjgeorge @blrcitytraffic The very fact tha...       en
# 2418      2418  @TimesNow Its a great job by the security forc...       en
# 2455      2455  This video, made me to keep my chocolate to se...       en
# 2572      2572  AAP ACE champions registered complaint with BB...       en
# 2772      2772  BBC News - Somalia attack: Death toll rises in...       en
# 3207      3207  Gauri Lankesh murderers came wit helmet, weren...       en
#
#      Country Category Sub_Category
# 42     India    Crime
# 70     India    Crime
# 182    India    Crime
# 257    India    Crime
# 331    India    Crime
# 471    India    Crime
# 482    India    Crime
# 576    India    Crime
# 607    India    Crime
# 652    India    Crime
# 737    India    Crime
# 999    India    Crime
# 1092   India    Crime
# 1096   India    Crime
# 1315   India    Crime
# 1614   India    Crime
# 1910   India    Crime
# 2214   India    Crime
# 2342   India    Crime
# 2361   India    Crime
# 2418   India    Crime
# 2455   India    Crime
# 2572   India    Crime
# 2772   India    Crime
# 3207   India    Crime

# %%
Tweets_Pothole = df[df.Tweet_Text.str.contains('pothole')]
Tweets_murder = df[df.Tweet_Text.str.contains('murder')]
Tweets_accident = df[df.Tweet_Text.str.contains('accident')]
Tweets_theft = df[df.Tweet_Text.str.contains('theft')]
Tweets_robbery = df[df.Tweet_Text.str.contains('robbery')]
Tweets_cruelty = df[df.Tweet_Text.str.contains('cruelty')]
Tweets_blast = df[df.Tweet_Text.str.contains('blast')]
Tweets_terror = df[df.Tweet_Text.str.contains('terror')]
Tweets_explosion = df[df.Tweet_Text.str.contains('explosion')]
Tweets_assault = df[df.Tweet_Text.str.contains('assault')]

# %%
Tweets_Pothole['Category'] = 'Crime'
Tweets_Pothole['Sub_Category'] = 'Pothole'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_Pothole
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 737        737  10+ ppl died in Bangalore due to potholes but ...       en
# 1614      1614  @BBMPCOMM1  Sir,Deadly Road conditions for two...       en
# 1910      1910   @TOIBengaluru As if pothole deaths wr not enough       en
# 2342      2342  No money for filling potholes,CM Karnataka spe...       en
# 2572      2572  AAP ACE champions registered complaint with BB...       en
#
#      Country Category Sub_Category
# 737    India    Crime      Pothole
# 1614   India    Crime      Pothole
# 1910   India    Crime      Pothole
# 2342   India    Crime      Pothole
# 2572   India    Crime      Pothole

# %%
Tweets_murder['Category'] = 'Crime'
Tweets_murder['Sub_Category'] = 'Murder'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_murder
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 257        257  https://t.co/7uGFf7937r\nBook @UIDAI for murde...       en
# 471        471  #GauriLankesh murder will remain forever  a my...       en
# 482        482  This is man who is accused of roits begining f...       en
# 1096      1096  Pinarayi Vijayan, the prime accused in Kerala’...       en
# 1315      1315  Siddaramaiah’s SIT probing Gauri Lankesh murde...       en
# 3207      3207  Gauri Lankesh murderers came wit helmet, weren...       en
#
#      Country Category Sub_Category
# 257    India    Crime       Murder
# 471    India    Crime       Murder
# 482    India    Crime       Murder
# 1096   India    Crime       Murder
# 1315   India    Crime       Murder
# 3207   India    Crime       Murder

# %%
Tweets_accident['Category'] = 'Crime'
Tweets_accident['Sub_Category'] = 'Accident'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_accident
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 331        331  Situation of Bangalore railway station. Inviti...       en
# 2361      2361  @thekjgeorge @blrcitytraffic The very fact tha...       en
#
#      Country Category Sub_Category
# 331    India    Crime     Accident
# 2361   India    Crime     Accident

# %%
Tweets_theft['Category'] = 'Crime'
Tweets_theft['Sub_Category'] = 'Theft'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_theft
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 2455      2455  This video, made me to keep my chocolate to se...       en
#
#      Country Category Sub_Category
# 2455   India    Crime        Theft

# %%
Tweets_blast['Category'] = 'Crime'
Tweets_blast['Sub_Category'] = 'Blast'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_blast
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 576        576  Death toll rises to 6 in Ejipura blast in #Ben...       en
# 607        607  Death toll rises to 6 in Ejipura cylinder blas...       en
# 652        652  Death toll rises to 5 in Ejipura cylinder blas...       en
# 2214      2214  Forensic team visits building collapse site at...       en
# 2772      2772  BBC News - Somalia attack: Death toll rises in...       en
#
#      Country Category Sub_Category
# 576    India    Crime        Blast
# 607    India    Crime        Blast
# 652    India    Crime        Blast
# 2214   India    Crime        Blast
# 2772   India    Crime        Blast

# %%
Tweets_explosion['Category'] = 'Crime'
Tweets_explosion['Sub_Category'] = 'Explosion'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_explosion
# Out:
#     Tweet_ID                                         Tweet_Text Language  \
# 42        42  4 people killed in building collapse after cyl...       en
# 70        70  4 people killed in building collapse after cyl...       en
#
#    Country Category Sub_Category
# 42   India    Crime    Explosion
# 70   India    Crime    Explosion

# %%
Tweets_terror['Category'] = 'Crime'
Tweets_terror['Sub_Category'] = 'Terror'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_terror
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 182        182  @TheAsianAgeNews And Tillerson wl say Pakistan...       en
# 999        999  @YusufDFI He's right. Rest of us are disposabl...       en
# 1092      1092  A Hindu Mutt Swamini attends a rally organized...       en
# 2418      2418  @TimesNow Its a great job by the security forc...       en
#
#      Country Category Sub_Category
# 182    India    Crime       Terror
# 999    India    Crime       Terror
# 1092   India    Crime       Terror
# 2418   India    Crime       Terror

# %%
Tweets_assault['Category'] = 'Crime'
Tweets_assault['Sub_Category'] = 'Assault'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_assault
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 474        474  Karnataka: Animal rights activist alleges mob ...       en
# 834        834  A woman from the majority community is brutall...       en
# 1780      1780  CM @siddaramaiah reacts to the techie assault,...       en
# 1786      1786  Hand in gloves. SHO wud ve informed d goons in...       en
# 2143      2143  Talaghattapura Police Inspector who colluded w...       en
# 2677      2677  I've never been assaulted and I don't know the...       en
# 3144      3144  This guy tweets on this issue, but not one twe...       en
#
#      Country Category Sub_Category
# 474    India    Crime      Assault
# 834    India    Crime      Assault
# 1780   India    Crime      Assault
# 1786   India    Crime      Assault
# 2143   India    Crime      Assault
# 2677   India    Crime      Assault
# 3144   India    Crime      Assault

# %%
#Concatenate the different dataframes to the original dataframe- df
Tweets_concat = pd.concat([Tweets_accident, Tweets_Pothole, Tweets_murder, Tweets_theft, Tweets_blast, Tweets_explosion, Tweets_terror, Tweets_assault, df])

# %%
#Display the concatenated dataframe
Tweets_concat
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 331        331  Situation of Bangalore railway station. Inviti...       en
# 2361      2361  @thekjgeorge @blrcitytraffic The very fact tha...       en
# 737        737  10+ ppl died in Bangalore due to potholes but ...       en
# 1614      1614  @BBMPCOMM1  Sir,Deadly Road conditions for two...       en
# 1910      1910   @TOIBengaluru As if pothole deaths wr not enough       en
# 2342      2342  No money for filling potholes,CM Karnataka spe...       en
# 2572      2572  AAP ACE champions registered complaint with BB...       en
# 257        257  https://t.co/7uGFf7937r\nBook @UIDAI for murde...       en
# 471        471  #GauriLankesh murder will remain forever  a my...       en
# 482        482  This is man who is accused of roits begining f...       en
# 1096      1096  Pinarayi Vijayan, the prime accused in Kerala’...       en
# 1315      1315  Siddaramaiah’s SIT probing Gauri Lankesh murde...       en
# 3207      3207  Gauri Lankesh murderers came wit helmet, weren...       en
# 2455      2455  This video, made me to keep my chocolate to se...       en
# 576        576  Death toll rises to 6 in Ejipura blast in #Ben...       en
# 607        607  Death toll rises to 6 in Ejipura cylinder blas...       en
# 652        652  Death toll rises to 5 in Ejipura cylinder blas...       en
# 2214      2214  Forensic team visits building collapse site at...       en
# 2772      2772  BBC News - Somalia attack: Death toll rises in...       en
# 42          42  4 people killed in building collapse after cyl...       en
# 70          70  4 people killed in building collapse after cyl...       en
# 182        182  @TheAsianAgeNews And Tillerson wl say Pakistan...       en
# 999        999  @YusufDFI He's right. Rest of us are disposabl...       en
# 1092      1092  A Hindu Mutt Swamini attends a rally organized...       en
# 2418      2418  @TimesNow Its a great job by the security forc...       en
# 474        474  Karnataka: Animal rights activist alleges mob ...       en
# 834        834  A woman from the majority community is brutall...       en
# 1780      1780  CM @siddaramaiah reacts to the techie assault,...       en
# 1786      1786  Hand in gloves. SHO wud ve informed d goons in...       en
# 2143      2143  Talaghattapura Police Inspector who colluded w...       en
# ...        ...                                                ...      ...
# 3576      3576  #food #foodie #snacks #nature nature foodyeati...       en
# 3577      3577  @ernestjeffry You mean 80 crores turnover or l...       en
# 3578      3578  પીએમ મોદીએ વેપારીઓને  કર્યો વાયદો, તમારા જુના ...       gu
# 3579      3579  $ULI.V up +18.92% last wk as #UltraLithium sam...       en
# 3580      3580  @iPallaviGoyal u can PLAY with this https://t....       en
# 3581      3581  One Stop solution for the complete #interiorde...       en
# 3582      3582                               @iPallaviGoyal "ALL"      und
# 3583      3583  કોંગ્રેસને પેટમાં દુખે છે અને માથું કુટે છેઃ વ...       gu
# 3584      3584  Can you recommend anyone for this #job? Projec...       en
# 3585      3585  Jacques Kallis, @jacqueskallis75 is now trendi...       en
# 3586      3586  @Swamy39 Rajdeep looked like a mental case aft...       en
# 3587      3587  'sangeet' &amp; 'blot' are now trending in #Ba...       en
# 3588      3588  All the best @NewtonTheFilm for being selected...       en
# 3589      3589  Why are rent agreements only for 11 months?\nh...       en
# 3590      3590                      @iPallaviGoyal &lt;--- STINKS       en
# 3591      3591           Thank you koko 🤗 https://t.co/N6dPr7zd8J       en
# 3592      3592     @iPallaviGoyal  &lt;-- BEGGING FOR HUMILIATION       en
# 3593      3593  Make it your twitter/insta/fb DP for his 23rd ...       en
# 3594      3594  1485sq.ft Plot w/ price of 20.79 lakhs is avai...       en
# 3595      3595  👀 Insider Tips on Broadway by @debbiedares in ...       en
# 3596      3596  And they say, #Kashmir belonged to them. 😂😂😂 h...       en
# 3597      3597                        +10 https://t.co/3emgBBHb3z      und
# 3598      3598  CRUDE OIL ROCKED FROM 3357 TO 3387 +30 PTS BOO...       en
# 3599      3599  HOLY SHIT 2018 @hellfestopenair TIX ARE ALREAD...       en
# 3600      3600  નોટબંધીના કારણે 3 લાખ કરોડ રૂપિયાનું સરકારને સ...       gu
# 3601      3601  @naralokesh Tirupati can be a bigger Eco-syste...       en
# 3602      3602  Rental Space Available for #CambridgeLayout #O...       en
# 3603      3603  Those questioning us on development of Gujarat...       en
# 3604      3604  $AWE.V up +18.75% last wk on no news: WATCH Br...       en
# 3605      3605             @iPallaviGoyal https://t.co/fgjxDy78Ij      und
#
#      Country Category Sub_Category
# 331    India    Crime     Accident
# 2361   India    Crime     Accident
# 737    India    Crime      Pothole
# 1614   India    Crime      Pothole
# 1910   India    Crime      Pothole
# 2342   India    Crime      Pothole
# 2572   India    Crime      Pothole
# 257    India    Crime       Murder
# 471    India    Crime       Murder
# 482    India    Crime       Murder
# 1096   India    Crime       Murder
# 1315   India    Crime       Murder
# 3207   India    Crime       Murder
# 2455   India    Crime        Theft
# 576    India    Crime        Blast
# 607    India    Crime        Blast
# 652    India    Crime        Blast
# 2214   India    Crime        Blast
# 2772   India    Crime        Blast
# 42     India    Crime    Explosion
# 70     India    Crime    Explosion
# 182    India    Crime       Terror
# 999    India    Crime       Terror
# 1092   India    Crime       Terror
# 2418   India    Crime       Terror
# 474    India    Crime      Assault
# 834    India    Crime      Assault
# 1780   India    Crime      Assault
# 1786   India    Crime      Assault
# 2143   India    Crime      Assault
# ...      ...      ...          ...
# 3576   India
# 3577   India
# 3578   India
# 3579   India
# 3580   India
# 3581   India
# 3582   India
# 3583   India
# 3584   India
# 3585   India
# 3586   India
# 3587   India
# 3588   India
# 3589   India
# 3590   India
# 3591   India
# 3592   India
# 3593   India
# 3594   India
# 3595   India
# 3596   India
# 3597   India
# 3598   India
# 3599   India
# 3600   India
# 3601   India
# 3602   India
# 3603   India
# 3604   India
# 3605   India
#
# [3638 rows x 6 columns]

# %%
Tweets_concat.shape
# Out:
# (3638, 6)

# %%
# Shows us how many duplicates are there in the Tweets
Tweets_concat.Tweet_ID.duplicated().sum()
# Out:
# 32

# %%
# Shows duplicates for the entire dataframe, only if an entire row matches any one above it.
Tweets_concat.duplicated().sum()
# Out:
# 0

# %%
# To see the actual duplicated rows if any.
Tweets_concat.loc[Tweets_concat.duplicated(), :]
# Out:
# Empty DataFrame
# Columns: [Tweet_ID, Tweet_Text, Language, Country, Category, Sub_Category]
# Index: []

# %%
Tweets_concat.duplicated(subset = ['Tweet_ID','Tweet_Text','Language','Country'],keep='last').sum()
# Out:
# 32

# %%
Tweets_concat.loc[Tweets_concat.duplicated(subset = ['Tweet_ID','Tweet_Text','Language','Country'],keep='last'), :]
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 331        331  Situation of Bangalore railway station. Inviti...       en
# 2361      2361  @thekjgeorge @blrcitytraffic The very fact tha...       en
# 737        737  10+ ppl died in Bangalore due to potholes but ...       en
# 1614      1614  @BBMPCOMM1  Sir,Deadly Road conditions for two...       en
# 1910      1910   @TOIBengaluru As if pothole deaths wr not enough       en
# 2342      2342  No money for filling potholes,CM Karnataka spe...       en
# 2572      2572  AAP ACE champions registered complaint with BB...       en
# 257        257  https://t.co/7uGFf7937r\nBook @UIDAI for murde...       en
# 471        471  #GauriLankesh murder will remain forever  a my...       en
# 482        482  This is man who is accused of roits begining f...       en
# 1096      1096  Pinarayi Vijayan, the prime accused in Kerala’...       en
# 1315      1315  Siddaramaiah’s SIT probing Gauri Lankesh murde...       en
# 3207      3207  Gauri Lankesh murderers came wit helmet, weren...       en
# 2455      2455  This video, made me to keep my chocolate to se...       en
# 576        576  Death toll rises to 6 in Ejipura blast in #Ben...       en
# 607        607  Death toll rises to 6 in Ejipura cylinder blas...       en
# 652        652  Death toll rises to 5 in Ejipura cylinder blas...       en
# 2214      2214  Forensic team visits building collapse site at...       en
# 2772      2772  BBC News - Somalia attack: Death toll rises in...       en
# 42          42  4 people killed in building collapse after cyl...       en
# 70          70  4 people killed in building collapse after cyl...       en
# 182        182  @TheAsianAgeNews And Tillerson wl say Pakistan...       en
# 999        999  @YusufDFI He's right. Rest of us are disposabl...       en
# 1092      1092  A Hindu Mutt Swamini attends a rally organized...       en
# 2418      2418  @TimesNow Its a great job by the security forc...       en
# 474        474  Karnataka: Animal rights activist alleges mob ...       en
# 834        834  A woman from the majority community is brutall...       en
# 1780      1780  CM @siddaramaiah reacts to the techie assault,...       en
# 1786      1786  Hand in gloves. SHO wud ve informed d goons in...       en
# 2143      2143  Talaghattapura Police Inspector who colluded w...       en
# 2677      2677  I've never been assaulted and I don't know the...       en
# 3144      3144  This guy tweets on this issue, but not one twe...       en
#
#      Country Category Sub_Category
# 331    India    Crime     Accident
# 2361   India    Crime     Accident
# 737    India    Crime      Pothole
# 1614   India    Crime      Pothole
# 1910   India    Crime      Pothole
# 2342   India    Crime      Pothole
# 2572   India    Crime      Pothole
# 257    India    Crime       Murder
# 471    India    Crime       Murder
# 482    India    Crime       Murder
# 1096   India    Crime       Murder
# 1315   India    Crime       Murder
# 3207   India    Crime       Murder
# 2455   India    Crime        Theft
# 576    India    Crime        Blast
# 607    India    Crime        Blast
# 652    India    Crime        Blast
# 2214   India    Crime        Blast
# 2772   India    Crime        Blast
# 42     India    Crime    Explosion
# 70     India    Crime    Explosion
# 182    India    Crime       Terror
# 999    India    Crime       Terror
# 1092   India    Crime       Terror
# 2418   India    Crime       Terror
# 474    India    Crime      Assault
# 834    India    Crime      Assault
# 1780   India    Crime      Assault
# 1786   India    Crime      Assault
# 2143   India    Crime      Assault
# 2677   India    Crime      Assault
# 3144   India    Crime      Assault

# %%
Tweets_concat.drop_duplicates(subset = ['Tweet_ID','Tweet_Text','Language','Country'], inplace=True)

# %%
Tweets_concat.Tweet_ID.duplicated().sum()
# Out:
# 0

# %%
Tweets_concat
# Out:
#       Tweet_ID                                         Tweet_Text Language  \
# 331        331  Situation of Bangalore railway station. Inviti...       en
# 2361      2361  @thekjgeorge @blrcitytraffic The very fact tha...       en
# 737        737  10+ ppl died in Bangalore due to potholes but ...       en
# 1614      1614  @BBMPCOMM1  Sir,Deadly Road conditions for two...       en
# 1910      1910   @TOIBengaluru As if pothole deaths wr not enough       en
# 2342      2342  No money for filling potholes,CM Karnataka spe...       en
# 2572      2572  AAP ACE champions registered complaint with BB...       en
# 257        257  https://t.co/7uGFf7937r\nBook @UIDAI for murde...       en
# 471        471  #GauriLankesh murder will remain forever  a my...       en
# 482        482  This is man who is accused of roits begining f...       en
# 1096      1096  Pinarayi Vijayan, the prime accused in Kerala’...       en
# 1315      1315  Siddaramaiah’s SIT probing Gauri Lankesh murde...       en
# 3207      3207  Gauri Lankesh murderers came wit helmet, weren...       en
# 2455      2455  This video, made me to keep my chocolate to se...       en
# 576        576  Death toll rises to 6 in Ejipura blast in #Ben...       en
# 607        607  Death toll rises to 6 in Ejipura cylinder blas...       en
# 652        652  Death toll rises to 5 in Ejipura cylinder blas...       en
# 2214      2214  Forensic team visits building collapse site at...       en
# 2772      2772  BBC News - Somalia attack: Death toll rises in...       en
# 42          42  4 people killed in building collapse after cyl...       en
# 70          70  4 people killed in building collapse after cyl...       en
# 182        182  @TheAsianAgeNews And Tillerson wl say Pakistan...       en
# 999        999  @YusufDFI He's right. Rest of us are disposabl...       en
# 1092      1092  A Hindu Mutt Swamini attends a rally organized...       en
# 2418      2418  @TimesNow Its a great job by the security forc...       en
# 474        474  Karnataka: Animal rights activist alleges mob ...       en
# 834        834  A woman from the majority community is brutall...       en
# 1780      1780  CM @siddaramaiah reacts to the techie assault,...       en
# 1786      1786  Hand in gloves. SHO wud ve informed d goons in...       en
# 2143      2143  Talaghattapura Police Inspector who colluded w...       en
# ...        ...                                                ...      ...
# 3576      3576  #food #foodie #snacks #nature nature foodyeati...       en
# 3577      3577  @ernestjeffry You mean 80 crores turnover or l...       en
# 3578      3578  પીએમ મોદીએ વેપારીઓને  કર્યો વાયદો, તમારા જુના ...       gu
# 3579      3579  $ULI.V up +18.92% last wk as #UltraLithium sam...       en
# 3580      3580  @iPallaviGoyal u can PLAY with this https://t....       en
# 3581      3581  One Stop solution for the complete #interiorde...       en
# 3582      3582                               @iPallaviGoyal "ALL"      und
# 3583      3583  કોંગ્રેસને પેટમાં દુખે છે અને માથું કુટે છેઃ વ...       gu
# 3584      3584  Can you recommend anyone for this #job? Projec...       en
# 3585      3585  Jacques Kallis, @jacqueskallis75 is now trendi...       en
# 3586      3586  @Swamy39 Rajdeep looked like a mental case aft...       en
# 3587      3587  'sangeet' &amp; 'blot' are now trending in #Ba...       en
# 3588      3588  All the best @NewtonTheFilm for being selected...       en
# 3589      3589  Why are rent agreements only for 11 months?\nh...       en
# 3590      3590                      @iPallaviGoyal &lt;--- STINKS       en
# 3591      3591           Thank you koko 🤗 https://t.co/N6dPr7zd8J       en
# 3592      3592     @iPallaviGoyal  &lt;-- BEGGING FOR HUMILIATION       en
# 3593      3593  Make it your twitter/insta/fb DP for his 23rd ...       en
# 3594      3594  1485sq.ft Plot w/ price of 20.79 lakhs is avai...       en
# 3595      3595  👀 Insider Tips on Broadway by @debbiedares in ...       en
# 3596      3596  And they say, #Kashmir belonged to them. 😂😂😂 h...       en
# 3597      3597                        +10 https://t.co/3emgBBHb3z      und
# 3598      3598  CRUDE OIL ROCKED FROM 3357 TO 3387 +30 PTS BOO...       en
# 3599      3599  HOLY SHIT 2018 @hellfestopenair TIX ARE ALREAD...       en
# 3600      3600  નોટબંધીના કારણે 3 લાખ કરોડ રૂપિયાનું સરકારને સ...       gu
# 3601      3601  @naralokesh Tirupati can be a bigger Eco-syste...       en
# 3602      3602  Rental Space Available for #CambridgeLayout #O...       en
# 3603      3603  Those questioning us on development of Gujarat...       en
# 3604      3604  $AWE.V up +18.75% last wk on no news: WATCH Br...       en
# 3605      3605             @iPallaviGoyal https://t.co/fgjxDy78Ij      und
#
#      Country Category Sub_Category
# 331    India    Crime     Accident
# 2361   India    Crime     Accident
# 737    India    Crime      Pothole
# 1614   India    Crime      Pothole
# 1910   India    Crime      Pothole
# 2342   India    Crime      Pothole
# 2572   India    Crime      Pothole
# 257    India    Crime       Murder
# 471    India    Crime       Murder
# 482    India    Crime       Murder
# 1096   India    Crime       Murder
# 1315   India    Crime       Murder
# 3207   India    Crime       Murder
# 2455   India    Crime        Theft
# 576    India    Crime        Blast
# 607    India    Crime        Blast
# 652    India    Crime        Blast
# 2214   India    Crime        Blast
# 2772   India    Crime        Blast
# 42     India    Crime    Explosion
# 70     India    Crime    Explosion
# 182    India    Crime       Terror
# 999    India    Crime       Terror
# 1092   India    Crime       Terror
# 2418   India    Crime       Terror
# 474    India    Crime      Assault
# 834    India    Crime      Assault
# 1780   India    Crime      Assault
# 1786   India    Crime      Assault
# 2143   India    Crime      Assault
# ...      ...      ...          ...
# 3576   India
# 3577   India
# 3578   India
# 3579   India
# 3580   India
# 3581   India
# 3582   India
# 3583   India
# 3584   India
# 3585   India
# 3586   India
# 3587   India
# 3588   India
# 3589   India
# 3590   India
# 3591   India
# 3592   India
# 3593   India
# 3594   India
# 3595   India
# 3596   India
# 3597   India
# 3598   India
# 3599   India
# 3600   India
# 3601   India
# 3602   India
# 3603   India
# 3604   India
# 3605   India
#
# [3606 rows x 6 columns]

# %%
# Write the dataframe to CSV file
#Tweets_concat.to_csv("d:\\Tweets_concat.csv", encoding='utf-8')
