# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('d://DataFiles_Backup//bangalore_22k.csv')

# %%
df.rename(columns = {'Unnamed: 0':'Tweet_ID'},inplace=True)

# %%
df.head()
# Out:
#   Tweet_ID                                         Tweet_Text  \
# 0        0  Machn wish u Happ birthday da  @ThalaSyed005 😍...
# 1        1  Not tryna be cool ✔ And I wanna feel it too\n📸...
# 2        2  Icardi, What a player. Inter stays within touc...
# 3        3  Will b d last day of all our #Mersal issues ! ...
# 4        4  Many ppl around the world r getting #Nougat 7....
#
#                     Time_Of_Tweet Tweet_Location  \
# 0  Mon Oct 16 03:54:44 +0000 2017      Bengaluru
# 1  Mon Oct 16 03:54:49 +0000 2017      Bengaluru
# 2  Mon Oct 16 03:55:14 +0000 2017      Bengaluru
# 3  Mon Oct 16 03:55:38 +0000 2017     Tamil Nadu
# 4  Mon Oct 16 03:56:04 +0000 2017      Bengaluru
#
#                                          Coordinates         User_Native  \
# 0  {u'type': u'Polygon', u'coordinates': [[[77.37...      Vellore, India
# 1  {u'type': u'Polygon', u'coordinates': [[[77.37...    Bengaluru, India
# ...

# %%
df.shape
# Out:
# (23120, 8)

# %%
df.dtypes
# Out:
# Tweet_ID          object
# Tweet_Text        object
# Time_Of_Tweet     object
# Tweet_Location    object
# Coordinates       object
# User_Native       object
# Country           object
# Language          object
# dtype: object

# %%
df
# Out:
#       Tweet_ID                                         Tweet_Text  \
# 0            0  Machn wish u Happ birthday da  @ThalaSyed005 😍...
# 1            1  Not tryna be cool ✔ And I wanna feel it too\n📸...
# 2            2  Icardi, What a player. Inter stays within touc...
# 3            3  Will b d last day of all our #Mersal issues ! ...
# 4            4  Many ppl around the world r getting #Nougat 7....
# 5            5  Samvat 2074 will see liquidity-valuations tuss...
# 6            6  @timesofindia Is this piece of news visible to...
# 7            7  When you lose your excuse, Results will be fou...
# 8            8  @CMofKarnataka pl read this. V all know that u...
# 9            9  @Rekhta \nखड़े हैं मुझको खरीदार देखने के लिए \...
# 10          10  The way you react towards a problem will deter...
# 11          11                                            Fguuuuu
# 12          12  @KVsayz Ee photo lo 7 gates unnay, 3 gates clo...
# ...

# %%
df['Time_Of_Tweet'] = pd.to_datetime(df['Time_Of_Tweet'], dayfirst=True, errors='coerce')

# %%
df.head()
# Out:
#   Tweet_ID                                         Tweet_Text  \
# 0        0  Machn wish u Happ birthday da  @ThalaSyed005 😍...
# 1        1  Not tryna be cool ✔ And I wanna feel it too\n📸...
# 2        2  Icardi, What a player. Inter stays within touc...
# 3        3  Will b d last day of all our #Mersal issues ! ...
# 4        4  Many ppl around the world r getting #Nougat 7....
#
#         Time_Of_Tweet Tweet_Location  \
# 0 2017-10-16 03:54:44      Bengaluru
# 1 2017-10-16 03:54:49      Bengaluru
# 2 2017-10-16 03:55:14      Bengaluru
# 3 2017-10-16 03:55:38     Tamil Nadu
# 4 2017-10-16 03:56:04      Bengaluru
#
#                                          Coordinates         User_Native  \
# 0  {u'type': u'Polygon', u'coordinates': [[[77.37...      Vellore, India
# 1  {u'type': u'Polygon', u'coordinates': [[[77.37...    Bengaluru, India
# 2  {u'type': u'Polygon', u'coordinates': [[[77.37...  Bangalore/Thrissur
# ...

# %%
df['Tweet_Text']
# Out:
# 0        Machn wish u Happ birthday da  @ThalaSyed005 😍...
# 1        Not tryna be cool ✔ And I wanna feel it too\n📸...
# 2        Icardi, What a player. Inter stays within touc...
# 3        Will b d last day of all our #Mersal issues ! ...
# 4        Many ppl around the world r getting #Nougat 7....
# 5        Samvat 2074 will see liquidity-valuations tuss...
# 6        @timesofindia Is this piece of news visible to...
# 7        When you lose your excuse, Results will be fou...
# 8        @CMofKarnataka pl read this. V all know that u...
# 9        @Rekhta \nखड़े हैं मुझको खरीदार देखने के लिए \...
# 10       The way you react towards a problem will deter...
# 11                                                 Fguuuuu
# 12       @KVsayz Ee photo lo 7 gates unnay, 3 gates clo...
# 13       Dear young bloods don't do dz kind of stunts @...
# 14       @KVsayz Podhunne akkadiki vellinattu unnaru ga...
# 15       @nimmaupendra \n\n Uಪ್ಪಿsm,. Forever https://t...
# ...

# %%
df['Category'] = ''
df['Sub_Category'] = ''

# %%
df.head()
# Out:
#   Tweet_ID                                         Tweet_Text  \
# 0        0  Machn wish u Happ birthday da  @ThalaSyed005 😍...
# 1        1  Not tryna be cool ✔ And I wanna feel it too\n📸...
# 2        2  Icardi, What a player. Inter stays within touc...
# 3        3  Will b d last day of all our #Mersal issues ! ...
# 4        4  Many ppl around the world r getting #Nougat 7....
#
#         Time_Of_Tweet Tweet_Location  \
# 0 2017-10-16 03:54:44      Bengaluru
# 1 2017-10-16 03:54:49      Bengaluru
# 2 2017-10-16 03:55:14      Bengaluru
# 3 2017-10-16 03:55:38     Tamil Nadu
# 4 2017-10-16 03:56:04      Bengaluru
#
#                                          Coordinates         User_Native  \
# 0  {u'type': u'Polygon', u'coordinates': [[[77.37...      Vellore, India
# 1  {u'type': u'Polygon', u'coordinates': [[[77.37...    Bengaluru, India
# 2  {u'type': u'Polygon', u'coordinates': [[[77.37...  Bangalore/Thrissur
# ...

# %%
df.dtypes
# Out:
# Tweet_ID                  object
# Tweet_Text                object
# Time_Of_Tweet     datetime64[ns]
# Tweet_Location            object
# Coordinates               object
# User_Native               object
# Country                   object
# Language                  object
# Category                  object
# Sub_Category              object
# dtype: object

# %%
Tweets_Categorized = df[(df.Tweet_Text.str.contains('pothole')) | (df.Tweet_Text.str.contains('murder')) | (df.Tweet_Text.str.contains('theft')) | (df.Tweet_Text.str.contains('robbery')) | (df.Tweet_Text.str.contains('accident')) | (df.Tweet_Text.str.contains('cruelty')) | (df.Tweet_Text.str.contains('blast')) | (df.Tweet_Text.str.contains('terror')) | (df.Tweet_Text.str.contains('explosion'))]

# %%
Tweets_Categorized['Category'] = 'Crime'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Tweets_Categorized
# Out:
#       Tweet_ID                                         Tweet_Text  \
# 42          42  4 people killed in building collapse after cyl...
# 70          70  4 people killed in building collapse after cyl...
# 182        182  @TheAsianAgeNews And Tillerson wl say Pakistan...
# 257        257  https://t.co/7uGFf7937r\nBook @UIDAI for murde...
# 331        331  Situation of Bangalore railway station. Inviti...
# 471        471  #GauriLankesh murder will remain forever  a my...
# 482        482  This is man who is accused of roits begining f...
# 576        576  Death toll rises to 6 in Ejipura blast in #Ben...
# 607        607  Death toll rises to 6 in Ejipura cylinder blas...
# 652        652  Death toll rises to 5 in Ejipura cylinder blas...
# 737        737  10+ ppl died in Bangalore due to potholes but ...
# 999        999  @YusufDFI He's right. Rest of us are disposabl...
# 1092      1092  A Hindu Mutt Swamini attends a rally organized...
# ...

# %%
Tweets_Pothole = df[df.Tweet_Text.str.contains('pothole')]
Tweets_murder = df[df.Tweet_Text.str.contains('murder')]
Tweets_accident = df[df.Tweet_Text.str.contains('accident')]
Tweets_theft = df[df.Tweet_Text.str.contains('theft')]
Tweets_robbery = df[df.Tweet_Text.str.contains('robbery')]
Tweets_cruelty = df[df.Tweet_Text.str.contains('cruelty')]
Tweets_blast = df[df.Tweet_Text.str.contains('blast')]
Tweets_terror = df[df.Tweet_Text.str.contains('terror')]
Tweets_explosion = df[df.Tweet_Text.str.contains('explosion')]
Tweets_assault = df[df.Tweet_Text.str.contains('assault')]
Tweets_snatching = df[df.Tweet_Text.str.contains('snatching')]
Tweets_snatch = df[df.Tweet_Text.str.contains('snatch')]

# %%
Tweets_Pothole['Category'] = 'Crime'
Tweets_Pothole['Sub_Category'] = 'Pothole'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_Pothole
# Out:
#       Tweet_ID                                         Tweet_Text  \
# 737        737  10+ ppl died in Bangalore due to potholes but ...
# 1614      1614  @BBMPCOMM1  Sir,Deadly Road conditions for two...
# 1910      1910   @TOIBengaluru As if pothole deaths wr not enough
# 2342      2342  No money for filling potholes,CM Karnataka spe...
# 2572      2572  AAP ACE champions registered complaint with BB...
# 3719      3719  Never been to Rohtang Pass? Come #Bengaluru ro...
# 7088      7088  Potholes in our cities have become as permanen...
# 9642      9642  Gold biscuit bonanza for Karnataka MLAs while ...
# 10685    10685  Some contractor has faced heavy losses filling...
# 13554    13553  Can see some potholes being filled in #Bengalu...
# 13561    13560  @BBMPCOMM1 due to the potholes and poor lighti...
# 13565    13564  The massive potholes are still getting bigger ...
# 13580    13579  Also, some potholes are left half-filled or ju...
# ...

# %%
Tweets_murder['Category'] = 'Crime'
Tweets_murder['Sub_Category'] = 'Murder'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_murder
# Out:
#       Tweet_ID                                         Tweet_Text  \
# 257        257  https://t.co/7uGFf7937r\nBook @UIDAI for murde...
# 471        471  #GauriLankesh murder will remain forever  a my...
# 482        482  This is man who is accused of roits begining f...
# 1096      1096  Pinarayi Vijayan, the prime accused in Kerala’...
# 1315      1315  Siddaramaiah’s SIT probing Gauri Lankesh murde...
# 3207      3207  Gauri Lankesh murderers came wit helmet, weren...
# 4110      4110  It is said that #GauriLankesh's killers were i...
# 6102      6102  We've constituted an SIT headed by DCP (invest...
# 6911      6911  Mr Swamy,apt reply for a wife murderer. https:...
# 7449      7449  @TimesNow our police is like a thief+ dacoit+m...
# 9354      9354  PM @NarendraModi becomes the 1st Prime Ministe...
# 9398      9398  You make movies rajputs, glorify bloody basted...
# 11392    11391  @tajmahalfoxtrot @scroll_in Tipu was a mass mu...
# ...

# %%
Tweets_accident['Category'] = 'Crime'
Tweets_accident['Sub_Category'] = 'Accident'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_accident
# Out:
#       Tweet_ID                                         Tweet_Text  \
# 331        331  Situation of Bangalore railway station. Inviti...
# 2361      2361  @thekjgeorge @blrcitytraffic The very fact tha...
# 4092      4092  it's like seeing an accident on the road and j...
# 4129      4129  @ZeeNews Actually She was to run after acciden...
# 4327      4327  Unfortunate accident Bangalore. Gas cylinder b...
# 4651      4651  J&amp;K: 5 members of a family died in a road ...
# 13561    13560  @BBMPCOMM1 due to the potholes and poor lighti...
# 13715    13714  @GandharvaRani Taking accident victims to hosp...
# 18213    18212  A car accident in #Jharkhand's Nimiaghat kille...
# 18507    18506  Soe (49) was returning to Kolkata from Gaya in...
# 20218    20217  @rsprasad @narendramodi  Need of the hour to N...
#
#             Time_Of_Tweet   Tweet_Location  \
# 331   2017-10-16 04:45:21        Bengaluru
# 2361  2017-10-16 09:10:45  Bengaluru South
# ...

# %%
Tweets_theft['Category'] = 'Crime'
Tweets_theft['Sub_Category'] = 'Theft'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_theft
# Out:
#      Tweet_ID                                         Tweet_Text  \
# 2455     2455  This video, made me to keep my chocolate to se...
#
#            Time_Of_Tweet Tweet_Location  \
# 2455 2017-10-16 09:27:02      Bengaluru
#
#                                             Coordinates User_Native Country  \
# 2455  {u'type': u'Polygon', u'coordinates': [[[77.37...   Bangalore   India
#
#      Language Category Sub_Category
# 2455       en    Crime        Theft

# %%
Tweets_blast['Category'] = 'Crime'
Tweets_blast['Sub_Category'] = 'Blast'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_blast
# Out:
#       Tweet_ID                                         Tweet_Text  \
# 576        576  Death toll rises to 6 in Ejipura blast in #Ben...
# 607        607  Death toll rises to 6 in Ejipura cylinder blas...
# 652        652  Death toll rises to 5 in Ejipura cylinder blas...
# 2214      2214  Forensic team visits building collapse site at...
# 2772      2772  BBC News - Somalia attack: Death toll rises in...
# 4327      4327  Unfortunate accident Bangalore. Gas cylinder b...
# 5209      5209              #HelloDiwali    ready for the blast??
# 7724      7724  #HimachalPradesh : One dead after a cylinder b...
# 7890      7890  @SrikarNTR Ah bomb blast episode teesesthe man...
# 7990      7990  #MostAwaitedFilmof2017..\nNow its no more..As ...
# 8608      8608  @KicchaSudeep happy deepawali Sudeep Anna. Hav...
# 12127    12126  @sivaramkrish13 @BCCI Yes agree  but 1 big exc...
# 15408    15407  Vijay 62 - conform with AR murugadhas \nBJP pl...
# ...

# %%
Tweets_explosion['Category'] = 'Crime'
Tweets_explosion['Sub_Category'] = 'Explosion'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_explosion
# Out:
#       Tweet_ID                                         Tweet_Text  \
# 42          42  4 people killed in building collapse after cyl...
# 70          70  4 people killed in building collapse after cyl...
# 9835      9835  #Odisha CM @Naveen_Odisha announces ex-gratia ...
# 10307    10307  Bot loses eyesight due to crackers explosion L...
# 10612    10612  Boy loses eyesight due to crackers explosion L...
#
#             Time_Of_Tweet Tweet_Location  \
# 42    2017-10-16 04:03:47      Bengaluru
# 70    2017-10-16 04:07:39      Bengaluru
# 9835  2017-10-18 16:55:19      Bengaluru
# 10307 2017-10-18 17:47:16      Bengaluru
# 10612 2017-10-18 18:29:37      Bengaluru
#
#                                              Coordinates User_Native Country  \
# 42     {u'type': u'Polygon', u'coordinates': [[[77.37...   BENGALURU   India
# 70     {u'type': u'Polygon', u'coordinates': [[[77.37...   BENGALURU   India
# 9835   {u'type': u'Polygon', u'coordinates': [[[77.37...   BENGALURU   India
# ...

# %%
Tweets_terror['Category'] = 'Crime'
Tweets_terror['Sub_Category'] = 'Terror'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_terror
# Out:
#       Tweet_ID                                         Tweet_Text  \
# 182        182  @TheAsianAgeNews And Tillerson wl say Pakistan...
# 999        999  @YusufDFI He's right. Rest of us are disposabl...
# 1092      1092  A Hindu Mutt Swamini attends a rally organized...
# 2418      2418  @TimesNow Its a great job by the security forc...
# 4253      4253  Nandini shud hv known that Karnataka is ruled ...
# 4658      4658  @terror_studies @Il_Post_Censura @CivilWarMap ...
# 4879      4879  3 terrorists fired &amp; killed former Sarpanc...
# 6204      6204  Delhi court discharges Maulana Anzar Shah in t...
# 8802      8802  US and India stand shoulder to shoulder agains...
# 10598    10598  Don't worry , our brave forces would take thes...
# 12108    12107  @WhatTheFFacts Why glorify cold blooded murder...
# 12362    12361  #CongressForAll terrorist related queries cont...
# 12848    12847  @abhilash1313 @prakashraaj go and see in Kashm...
# ...

# %%
Tweets_assault['Category'] = 'Crime'
Tweets_assault['Sub_Category'] = 'Assault'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_assault
# Out:
#       Tweet_ID                                         Tweet_Text  \
# 474        474  Karnataka: Animal rights activist alleges mob ...
# 834        834  A woman from the majority community is brutall...
# 1780      1780  CM @siddaramaiah reacts to the techie assault,...
# 1786      1786  Hand in gloves. SHO wud ve informed d goons in...
# 2143      2143  Talaghattapura Police Inspector who colluded w...
# 2677      2677  I've never been assaulted and I don't know the...
# 3144      3144  This guy tweets on this issue, but not one twe...
# 4231      4231  All u girls out there who have gone thru a sex...
# 4243      4243  To all men who are saying "it happens with men...
# 5807      5807  Cow protection activists were assaulted in MS ...
# 7068      7068  Kashmiri was the part of #UndividedIndia and t...
# 8282      8282  No woman, man or child is to blame for being s...
# 11392    11391  @tajmahalfoxtrot @scroll_in Tipu was a mass mu...
# ...

# %%
Tweets_snatching['Category'] = 'Crime'
Tweets_snatching['Sub_Category'] = 'Snatching'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_snatching
# Out:
#      Tweet_ID                                         Tweet_Text  \
# 7355     7355  @BlrCityPolice called 100 today to report on a...
#
#            Time_Of_Tweet Tweet_Location  \
# 7355 2017-10-17 16:43:50       JP Nagar
#
#                                             Coordinates User_Native Country  \
# 7355  {u'type': u'Polygon', u'coordinates': [[[77.56...  Bangalore    India
#
#      Language Category Sub_Category
# 7355       en    Crime    Snatching

# %%
Tweets_snatching['Category'] = 'Crime'
Tweets_snatch['Sub_Category'] = 'Snatch'
# Out:
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dell 7548\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Tweets_snatch
# Out:
#      Tweet_ID                                         Tweet_Text  \
# 4820     4820  Mam you were trying to snatch hafta from the p...
# 7355     7355  @BlrCityPolice called 100 today to report on a...
#
#            Time_Of_Tweet Tweet_Location  \
# 4820 2017-10-16 17:18:41      Bengaluru
# 7355 2017-10-17 16:43:50       JP Nagar
#
#                                             Coordinates User_Native Country  \
# 4820  {u'type': u'Polygon', u'coordinates': [[[77.37...         NaN   India
# 7355  {u'type': u'Polygon', u'coordinates': [[[77.56...  Bangalore    India
#
#      Language Category Sub_Category
# 4820       en                Snatch
# 7355       en                Snatch

# %%
#Concatenate the different dataframes to the original dataframe- df
Tweets_concat = pd.concat([Tweets_accident, Tweets_Pothole, Tweets_murder, Tweets_theft, Tweets_blast, Tweets_explosion, Tweets_terror, Tweets_assault, Tweets_snatching, Tweets_snatch, df])

# %%
#Display the concatenated dataframe
Tweets_concat
# Out:
#       Tweet_ID                                         Tweet_Text  \
# 331        331  Situation of Bangalore railway station. Inviti...
# 2361      2361  @thekjgeorge @blrcitytraffic The very fact tha...
# 4092      4092  it's like seeing an accident on the road and j...
# 4129      4129  @ZeeNews Actually She was to run after acciden...
# 4327      4327  Unfortunate accident Bangalore. Gas cylinder b...
# 4651      4651  J&amp;K: 5 members of a family died in a road ...
# 13561    13560  @BBMPCOMM1 due to the potholes and poor lighti...
# 13715    13714  @GandharvaRani Taking accident victims to hosp...
# 18213    18212  A car accident in #Jharkhand's Nimiaghat kille...
# 18507    18506  Soe (49) was returning to Kolkata from Gaya in...
# 20218    20217  @rsprasad @narendramodi  Need of the hour to N...
# 737        737  10+ ppl died in Bangalore due to potholes but ...
# 1614      1614  @BBMPCOMM1  Sir,Deadly Road conditions for two...
# ...

# %%
Tweets_concat.shape
# Out:
# (23239, 10)

# %%
# Shows us how many duplicates are there in the Tweets
Tweets_concat.Tweet_ID.duplicated().sum()
# Out:
# 119

# %%
# Shows duplicates for the entire dataframe, only if an entire row matches any one above it.
Tweets_concat.duplicated().sum()
# Out:
# 0

# %%
# To see the actual duplicated rows if any.
Tweets_concat.loc[Tweets_concat.duplicated(), :]
# Out:
# Empty DataFrame
# Columns: [Tweet_ID, Tweet_Text, Time_Of_Tweet, Tweet_Location, Coordinates, User_Native, Country, Language, Category, Sub_Category]
# Index: []

# %%
Tweets_concat.duplicated(subset = ['Tweet_ID','Tweet_Text','Language','Country'],keep='last').sum()
# Out:
# 119

# %%
Tweets_concat.loc[Tweets_concat.duplicated(subset = ['Tweet_ID','Tweet_Text','Language','Country'],keep='last'), :]
# Out:
#       Tweet_ID                                         Tweet_Text  \
# 331        331  Situation of Bangalore railway station. Inviti...
# 2361      2361  @thekjgeorge @blrcitytraffic The very fact tha...
# 4092      4092  it's like seeing an accident on the road and j...
# 4129      4129  @ZeeNews Actually She was to run after acciden...
# 4327      4327  Unfortunate accident Bangalore. Gas cylinder b...
# 4651      4651  J&amp;K: 5 members of a family died in a road ...
# 13561    13560  @BBMPCOMM1 due to the potholes and poor lighti...
# 13715    13714  @GandharvaRani Taking accident victims to hosp...
# 18213    18212  A car accident in #Jharkhand's Nimiaghat kille...
# 18507    18506  Soe (49) was returning to Kolkata from Gaya in...
# 20218    20217  @rsprasad @narendramodi  Need of the hour to N...
# 737        737  10+ ppl died in Bangalore due to potholes but ...
# 1614      1614  @BBMPCOMM1  Sir,Deadly Road conditions for two...
# ...

# %%
Tweets_concat.drop_duplicates(subset = ['Tweet_ID','Tweet_Text','Language','Country'], inplace=True)

# %%
Tweets_concat.Tweet_ID.duplicated().sum()
# Out:
# 0

# %%
#Tweets_concat.sort_values('Tweet_ID',inplace=True)
Tweets_concat.sort_values('Sub_Category',ascending=False,inplace=True)

# %%
Tweets_concat
# Out:
#       Tweet_ID                                         Tweet_Text  \
# 2455      2455  This video, made me to keep my chocolate to se...
# 17647    17646  Most shameful incident.... conspiracy to defam...
# 15185    15184  Prime Minister Narendra Modi and Ashraf Ghani ...
# 14945    14944  @TimesNow Army has to firmly deal with local a...
# 14878    14877  @TimesNow Perhaps the US has understood Pak's ...
# 12848    12847  @abhilash1313 @prakashraaj go and see in Kashm...
# 12362    12361  #CongressForAll terrorist related queries cont...
# 10598    10598  Don't worry , our brave forces would take thes...
# 8802      8802  US and India stand shoulder to shoulder agains...
# 6204      6204  Delhi court discharges Maulana Anzar Shah in t...
# 4879      4879  3 terrorists fired &amp; killed former Sarpanc...
# 4658      4658  @terror_studies @Il_Post_Censura @CivilWarMap ...
# 4253      4253  Nandini shud hv known that Karnataka is ruled ...
# ...

# %%
# Write the dataframe to CSV file
#Tweets_concat.to_csv("d:\\Tweets_concat.csv", encoding='utf-8')

# %%
Crimes_Grouped = Tweets_concat.groupby(['Sub_Category','Tweet_Location']).Tweet_Location.count()

# %%
pd.crosstab(Tweets_concat.Sub_Category, Tweets_concat.Tweet_Location)
# Out:
# Tweet_Location  Andhra Pradesh  Anekal Bangaluru  Ashok Nagar  Banashankari  \
# Sub_Category
#                            527               389           72             4
# Accident                     0                 0            0             0
# Assault                      0                 0            0             0
# Blast                        1                 0            0             0
# Explosion                    0                 0            0             0
# Murder                       0                 0            0             0
# Pothole                      0                 1            0             0
# Snatch                       0                 0            0             0
# Snatching                    0                 0            0             0
# Terror                       0                 0            0             0
# Theft                        0                 0            0             0
#
# ...

# %%
Tweets_crimes = pd.concat([Tweets_accident, Tweets_Pothole, Tweets_murder, Tweets_theft, Tweets_blast, Tweets_explosion, Tweets_terror, Tweets_assault, Tweets_snatching, Tweets_snatch])

# %%
Tweets_crimes.shape
# Out:
# (119, 10)

# %%
pd.crosstab(Tweets_crimes.Sub_Category, Tweets_crimes.Tweet_Location)
# Out:
# Tweet_Location  Andhra Pradesh  Anekal Bangaluru  Bengaluru  Bengaluru South  \
# Sub_Category
# Accident                     0                 0          9                2
# Assault                      0                 0          8                4
# Blast                        1                 0          7                5
# Explosion                    0                 0          5                0
# Murder                       0                 0         14                5
# Pothole                      0                 1          9                8
# Snatch                       0                 0          1                0
# Snatching                    0                 0          0                0
# Terror                       0                 0         22                2
# Theft                        0                 0          1                0
#
# Tweet_Location  India  JP Nagar  Karnataka  Tamil Nadu
# Sub_Category
# ...

# %%
# %matplotlib inline

# %%
Tweets_crimes.groupby(['Sub_Category']).Tweet_Location.count().plot(kind='bar')

# %%
Tweets_crimes.groupby(['Sub_Category','Tweet_Location']).Tweet_Location.count().plot(kind='bar')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
subset = Tweets_crimes[['Tweet_ID', 'Sub_Category','Tweet_Location']]

# %%
subset_pivot = pd.pivot_table(subset, index=['Sub_Category','Tweet_Location'],values=['Sub_Category'], aggfunc='count')
type(subset_pivot)
# Out:
# pandas.core.frame.DataFrame

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (15,14));

filt_data = Tweets_crimes[['Sub_Category', 'Tweet_Location', 'Tweet_ID']];
filt_data = filt_data.groupby(['Sub_Category', 'Tweet_Location']).count();
filt_data = filt_data.reset_index();
pivot_0_0 = filt_data.pivot('Sub_Category', 'Tweet_Location', 'Tweet_ID');
sns.heatmap(pivot_0_0, annot=True, fmt=".1f", linewidths=.5, square = True, cmap = 'Reds_r', ax = axes[0], cbar = False);

# %%
subset.Tweet_Location.value_counts().plot(kind='bar')

# %%
#Tweets_crimes['freq'] = Tweets_crimes.groupby('Tweet_Location')['Tweet_Location'].transform('count')

# %%
#import matplotlib.pyplot as plt
#import numpy as np

#data = subset_pivot.values
#test = data.reshape(50,50)
#rows = Tweets_crimes['Sub_Category'].unique()
#columns = Tweets_crimes['Tweet_Location'].unique()

# %%
#Tweets_crimes.to_csv("d:\\Tweets_crimes.csv", encoding='utf-8')

# %%
a = Tweets_crimes['Coordinates']
long = []
lat = []
for each in a:
    lo = each[41:-87]
    long.append(lo)
    la = each[52:-76]
    lat.append(la)
print(long)
print('\n')
print(lat)
# Out:
# ['77.373474', '77.330578', '77.373474', '77.373474', '77.373474', '77.373474', '77.330578', '77.373474', '77.373474', '77.373474', '77.373474', '67.9976', '77.556362', '77.373474', '77.330578', '77.373474', '77.373474', '77.373474', '77.330578', '77.330578', '77.373474', '77.330578', '77.373474', '77.373474', '77.373474', '77.330578', '77.330578', '77.330578', '77.373474', '77.330578', '77.373474', '77.373474', '77.373474', '77.373474', '77.330578', '77.330578', '77.373474', '67.9976', '77.373474', '77.373474', '77.373474', '77.373474', '77.330578', '77.373474', '77.373474', '67.9976', '77.373474', '77.373474', '77.373474', '67.9976', '77.330578', '77.330578', '77.373474', '77.373474', '77.373474', '77.373474', '77.373474', '74.050963', '77.373474', '67.9976', '77.373474', '77.330578', '76.7608', '77.330578', '77.330578', '76.23', '77.330578', '77.330578', '77.373474', '77.373474', '77.373474', '77.373474', '77.373474', '77.373474', '77.373474', '77.330578', '77.373474', '77.373474',
# ...

# %%
Tweets_crimes['Latitude'] = lat
Tweets_crimes['Longitude'] = long
Tweets_crimes.head()
# Out:
#      Tweet_ID                                         Tweet_Text  \
# 331       331  Situation of Bangalore railway station. Inviti...
# 2361     2361  @thekjgeorge @blrcitytraffic The very fact tha...
# 4092     4092  it's like seeing an accident on the road and j...
# 4129     4129  @ZeeNews Actually She was to run after acciden...
# 4327     4327  Unfortunate accident Bangalore. Gas cylinder b...
#
#            Time_Of_Tweet   Tweet_Location  \
# 331  2017-10-16 04:45:21        Bengaluru
# 2361 2017-10-16 09:10:45  Bengaluru South
# 4092 2017-10-16 15:41:09        Bengaluru
# 4129 2017-10-16 15:46:49        Bengaluru
# 4327 2017-10-16 16:11:36        Bengaluru
#
#                                             Coordinates  \
# 331   {u'type': u'Polygon', u'coordinates': [[[77.37...
# 2361  {u'type': u'Polygon', u'coordinates': [[[77.33...
# 4092  {u'type': u'Polygon', u'coordinates': [[[77.37...
# 4129  {u'type': u'Polygon', u'coordinates': [[[77.37...
# ...
